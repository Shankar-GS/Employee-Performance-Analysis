# %% [markdown]
# # External Data

# %% [markdown]
# - The data can be downloaded from the below link http://data.iabac.org/exam/p2/data/INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls

# %%
import pandas as pd
# Importing data from the dataset
Emp_Per=pd.read_excel('INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls')
#Reading the first 3 rows
Emp_Per.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# 0                  3        ...                                    4
# ...

# %% [markdown]
# # Processed Data

# %%
#Seting the target and predictor variables
X=Emp_Per.loc[:,'Age':'Attrition']
y=Emp_Per.loc[:,'PerformanceRating']

# %%
# Datasets for Modelling
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=5)

# %%
# data used for training
X
# Out:
#       Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  \
# 0      32       1                    2              2              5
# 1      47       1                    2              2              5
# 2      40       1                    1              1              5
# 3      41       1                    0              0              3
# 4      60       1                    2              2              5
# 5      27       1                    1              0              1
# 6      50       1                    2              1              5
# 7      28       0                    1              2              1
# 8      36       0                    1              1              1
# 9      38       0                    1              2              1
# 10     44       1                    3              2              1
# 11     47       0                    3              0              5
# 12     30       1                    2              0              5
# ...

# %%
#Data used for Testing
y
# Out:
# 0       3
# 1       3
# 2       4
# 3       3
# 4       3
# 5       4
# 6       3
# 7       3
# 8       3
# 9       3
# 10      3
# 11      3
# 12      4
# 13      3
# 14      3
# 15      3
# 16      3
# 17      3
# 18      4
# 19      3
# 20      3
# 21      3
# 22      3
# 23      3
# 24      3
# 25      4
# 26      3
# 27      4
# 28      3
# 29      3
#        ..
# 1170    3
# 1171    3
# 1172    3
# 1173    3
# 1174    3
# 1175    3
# 1176    3
# 1177    3
# 1178    3
# 1179    3
# 1180    4
# 1181    3
# 1182    3
# 1183    3
# 1184    3
# 1185    3
# 1186    3
# 1187    3
# 1188    3
# 1189    3
# 1190    4
# 1191    4
# 1192    4
# 1193    3
# 1194    3
# 1195    4
# 1196    3
# 1197    3
# 1198    3
# 1199    2
# Name: PerformanceRating, Length: 1200, dtype: int64

# %%
#Data used for X_train
X_train
# Out:
#       Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  \
# 811    35       0                    3              1              1
# 875    26       0                    1              1              3
# 691    32       0                    3              0              4
# 1187   36       1                    3              0              1
# 657    27       0                    3              2              5
# 1047   37       1                    3              0              1
# 193    37       0                    4              2              4
# 628    43       1                    1              1              5
# 796    27       0                    1              0              1
# 832    55       1                    1              1              5
# 287    36       0                    5              0              4
# 601    36       1                    1              1              4
# 222    45       0                    1              1              5
# ...

# %%
#Data used for X_test
X_test
# Out:
#       Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  \
# 984    28       1                    1              2              1
# 887    53       1                    2              1              5
# 11     47       0                    3              0              5
# 235    35       1                    2              0              5
# 596    21       1                    2              2              5
# 106    20       0                    3              2              5
# 820    45       1                    1              0              1
# 469    30       1                    5              1              5
# 515    24       0                    5              2              2
# 312    51       1                    1              0              5
# 1066   40       1                    2              1              5
# 34     26       0                    1              0              1
# 346    35       1                    1              2              4
# ...

# %%
#Data used for y_train
y_train
# Out:
# 811     3
# 875     4
# 691     3
# 1187    3
# 657     3
# 1047    3
# 193     3
# 628     2
# 796     3
# 832     3
# 287     4
# 601     3
# 222     2
# 244     3
# 228     3
# 505     3
# 439     3
# 133     3
# 392     3
# 126     3
# 823     4
# 1150    4
# 533     3
# 247     3
# 349     3
# 212     2
# 1075    3
# 856     3
# 1006    3
# 779     3
#        ..
# 676     3
# 1134    2
# 900     2
# 768     4
# 5       4
# 974     3
# 1168    3
# 103     3
# 210     3
# 41      3
# 377     2
# 146     4
# 1110    3
# 1089    3
# 205     2
# 1068    3
# 27      4
# 1104    3
# 1137    2
# 204     2
# 670     3
# 624     3
# 411     2
# 740     2
# 1032    3
# 73      3
# 1142    3
# 998     3
# 206     3
# 867     3
# Name: PerformanceRating, Length: 900, dtype: int64

# %%
#Data used for y_test
y_test
# Out:
# 984     3
# 887     2
# 11      3
# 235     3
# 596     3
# 106     3
# 820     3
# 469     3
# 515     2
# 312     4
# 1066    3
# 34      3
# 346     3
# 782     3
# 567     3
# 915     3
# 688     2
# 583     3
# 514     2
# 166     3
# 655     2
# 1188    3
# 517     3
# 1022    3
# 149     4
# 552     3
# 40      3
# 344     3
# 760     3
# 559     3
#        ..
# 680     4
# 545     4
# 921     3
# 1049    3
# 434     3
# 458     2
# 486     3
# 492     2
# 1166    3
# 561     2
# 819     4
# 1012    3
# 542     2
# 203     4
# 932     3
# 284     4
# 446     3
# 573     3
# 556     3
# 791     3
# 1058    3
# 8       3
# 883     3
# 675     3
# 213     3
# 1087    4
# 672     2
# 807     3
# 390     3
# 198     3
# Name: PerformanceRating, Length: 300, dtype: int64

# %%
# Deploying Model to use it in the real service
from sklearn.externals import joblib
joblib.dump(RFC,"Emp_Perf.ml")
# Out:
# ['Emp_Perf.ml']

# %% [markdown]
# # Raw Data

# %%
Emp_Per
# Out:
#      EmpNumber  Age  Gender  EducationBackground  MaritalStatus  \
# 0     E1001000   32       1                    2              2
# 1     E1001006   47       1                    2              2
# 2     E1001007   40       1                    1              1
# 3     E1001009   41       1                    0              0
# 4     E1001010   60       1                    2              2
# 5     E1001011   27       1                    1              0
# 6     E1001016   50       1                    2              1
# 7     E1001019   28       0                    1              2
# 8     E1001020   36       0                    1              1
# 9     E1001021   38       0                    1              2
# 10    E1001022   44       1                    3              2
# 11    E1001024   47       0                    3              0
# 12    E1001025   30       1                    2              0
# 13    E1001027   29       1                    1              2
# ...
